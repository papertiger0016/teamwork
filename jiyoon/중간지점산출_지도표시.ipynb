# %%
# !pip install googlemaps
# !pip install folium
# !pip install haversine
# Out:
# ...
#   Created wheel for googlemaps: filename=googlemaps-4.5.3-py3-none-any.whl size=38479 sha256=3d8f8abafec71129b9135468c89c0b95f7fc5a4ef2549975826411ae2c23267f
#   Stored in directory: /root/.cache/pip/wheels/fa/1a/1c/cc0b8a1652a3f06aea586b0e4714a81bafed830513969baf92
# Successfully built googlemaps
# ...

# %%
import googlemaps
import folium
from haversine import haversine

# %%
gmaps = googlemaps.Client(key='AIzaSyCNetZW4eZiBmY7Zlwa9IDOj1CtZhgm_a0')

# %%
def center_pointer(num_points):
    latitude=[]
    longitude=[]
    coordinate=[]
    
    global center_point
    
    for i in range(num_points):
        address = input("도로명주소를 입력하세요: ")
        geocode_result = gmaps.geocode(address)
        geometry=geocode_result[0].get("geometry")
        location=geometry.get("location")
        lng=location.get("lng")
        lat=location.get("lat")
        latitude.append(lat)
        longitude.append(lng)
        coordinate.append((lat, lng))

    center_point=(sum(latitude)/len(latitude), sum(longitude)/len(longitude))
    map=folium.Map(location=[center_point[0], center_point[1]], zoom_start=12)
    folium.Marker([center_point[0], center_point[1]], popup="center", icon=folium.Icon(color="red")).add_to(map)
    folium.CircleMarker([center_point[0], center_point[1]], radius=50, color="skyblue", fill_color="skyblue").add_to(map)
    for i in range(len(coordinate)):
        folium.Marker([latitude[i], longitude[i]], popup="출발지점 {}, {}km 거리입니다.".format(i, round(haversine(coordinate[i], center_point), 2))).add_to(map)
        folium.PolyLine(locations=[coordinate[i], center_point],weight=2, color = 'blue').add_to(map)
    return map

# %%
center_pointer(3)
# Out:
# 도로명주소를 입력하세요: 서울 서초구 사평대로 285
# 도로명주소를 입력하세요: 서울 동작구 상도로 188
# 도로명주소를 입력하세요: 서울 마포구 신촌로 270
# (37.52185673333333, 126.9700421)
# ...

# %%
import pandas as pd
df_store = pd.read_excel("data/망고플레이트 리뷰 종합.xlsx")

# %%
df_store
# Out:
#        Unnamed: 0       이름       평점                       주소            주력 메뉴  \
# 0          3869.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# 1          3865.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# 2          3867.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# 3          3868.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# 4          3863.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# ...           ...      ...      ...                      ...              ...
# 36203         NaN  키미노돼지국밥        -  서울특별시 중랑구 중랑천로10길 92 1F  \n탕 / 찌개 / 전골\n
# 36204         NaN    조개나루터        -     서울특별시 중랑구 중랑천로12길 59       \n해산물 요리\n
# 36205         NaN    조개나루터        -     서울특별시 중랑구 중랑천로12길 59       \n해산물 요리\n
# 36206         NaN    제주돈선생        -     서울특별시 중랑구 중랑천로12길 61        \n고기 요리\n
# 36207         NaN    제주돈선생        -     서울특별시 중랑구 중랑천로12길 61        \n고기 요리\n
#
# ...

# %%
df_store = df_store.replace('\n','', regex=True)

# %%
df_store
# Out:
#        Unnamed: 0       이름   평점                       주소        주력 메뉴     가격대  \
# 0          3869.0     청우참치  4.5       서울특별시 강남구 강남대로 632       회 / 스시  4만원 이상
# 1          3865.0     청우참치  4.5       서울특별시 강남구 강남대로 632       회 / 스시  4만원 이상
# 2          3867.0     청우참치  4.5       서울특별시 강남구 강남대로 632       회 / 스시  4만원 이상
# 3          3868.0     청우참치  4.5       서울특별시 강남구 강남대로 632       회 / 스시  4만원 이상
# 4          3863.0     청우참치  4.5       서울특별시 강남구 강남대로 632       회 / 스시  4만원 이상
# ...           ...      ...  ...                      ...          ...     ...
# 36203         NaN  키미노돼지국밥    -  서울특별시 중랑구 중랑천로10길 92 1F  탕 / 찌개 / 전골   만원 미만
# 36204         NaN    조개나루터    -     서울특별시 중랑구 중랑천로12길 59       해산물 요리     NaN
# 36205         NaN    조개나루터    -     서울특별시 중랑구 중랑천로12길 59       해산물 요리     NaN
# 36206         NaN    제주돈선생    -     서울특별시 중랑구 중랑천로12길 61        고기 요리  만원-2만원
# 36207         NaN    제주돈선생    -     서울특별시 중랑구 중랑천로12길 61        고기 요리  만원-2만원
#
# ...

# %%
del df_store['Unnamed: 0']

# %%
from tqdm import tqdm
import time

# %%
# center_point의 주소 
center_addr = gmaps.reverse_geocode((center_point), language='ko')[0]['formatted_address']

# %%
# 먼저 center_point와 같은 구인 가게 추출 (시간을 줄이기 위해서)
store_list = []
for i in df_store.index:
    if (center_addr[11:13] in df_store['주소'][i]):
        store_list.append(df_store.loc[i])
store_list = pd.DataFrame(store_list)

# %%
# 그 중 center_point로부터 1km 이내의 가게들만 추출
store = []
for i in tqdm(store_list.index):
    result = gmaps.geocode(store_list['주소'][i])
    geometry = result[0].get("geometry")
    lat = geometry['location']['lat'] # 가게 위도
    lng = geometry['location']['lng'] # 가게 경도
    point = lat,lng

    if (haversine(point, center_point)) <= 1:
        store.append(df_store.loc[i])
print(store)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 2343/2343 [04:40<00:00,  8.34it/s]
# [이름                                                        잭슨피자
# 평점                                                         4.4
# 주소                                서울특별시 용산구 서빙고로 67 상가 1F B12호
# 주력 메뉴                                                    기타 양식
# 가격대                                                     만원-2만원
# 망고플레이트 주소    https://www.mangoplate.com//restaurants/L34gox...
# 리뷰내용                   #잭슨피자인근 공원에서 배달로도 즐기기 좋은 잭슨피자하와이안, 수...
# Name: 28278, dtype: object, 이름                                                        잭슨피자
# 평점                                                         4.4
# 주소                                서울특별시 용산구 서빙고로 67 상가 1F B12호
# 주력 메뉴                                                    기타 양식
# 가격대                                                     만원-2만원
# 망고플레이트 주소    https://www.mangoplate.com//restaurants/L34gox...
# ...

# %%
store = pd.DataFrame(store)
store
# Out:
#           이름   평점                            주소            주력 메뉴     가격대  \
# 28278   잭슨피자  4.4  서울특별시 용산구 서빙고로 67 상가 1F B12호            기타 양식  만원-2만원
# 28279   잭슨피자  4.4  서울특별시 용산구 서빙고로 67 상가 1F B12호            기타 양식  만원-2만원
# 28280   잭슨피자  4.4  서울특별시 용산구 서빙고로 67 상가 1F B12호            기타 양식  만원-2만원
# 28281   잭슨피자  4.4  서울특별시 용산구 서빙고로 67 상가 1F B12호            기타 양식  만원-2만원
# 28282   잭슨피자  4.4  서울특별시 용산구 서빙고로 67 상가 1F B12호            기타 양식  만원-2만원
# ...      ...  ...                           ...              ...     ...
# 29553  더백테라스  4.3       서울특별시 용산구 한강대로40길 26 3F  브런치 / 버거 / 샌드위치   만원 미만
# 29554  더백테라스  4.3       서울특별시 용산구 한강대로40길 26 3F  브런치 / 버거 / 샌드위치   만원 미만
# 29555  더백테라스  4.3       서울특별시 용산구 한강대로40길 26 3F  브런치 / 버거 / 샌드위치   만원 미만
# 29556  더백테라스  4.3       서울특별시 용산구 한강대로40길 26 3F  브런치 / 버거 / 샌드위치   만원 미만
# 29557  더백테라스  4.3       서울특별시 용산구 한강대로40길 26 3F  브런치 / 버거 / 샌드위치   만원 미만
#
#                                                망고플레이트 주소  \
# ...

# %%
store_name = store.drop_duplicates(['이름'])
store_name
# Out:
#             이름   평점                                      주소            주력 메뉴  \
# 28278     잭슨피자  4.4            서울특별시 용산구 서빙고로 67 상가 1F B12호            기타 양식
# 28639  오근내 닭갈비  4.2                     서울특별시 용산구 이촌로29길 15        닭 / 오리 요리
# 28654       더몽  4.2                   서울특별시 용산구 이촌로75길 16-9    정통 중식 / 일반 중식
# 28662   한길포장마차  4.3                   서울특별시 용산구 이촌로75길 16-9       전통 주점 / 포차
# 28671     더 아래  4.1                서울특별시 용산구 이촌로84길 9-18 B1         칵테일 / 와인
# 29391   티하우스레몬  4.3  서울특별시 용산구 한강대로 95 래미안 용산더센트럴 B2 16-17호         카페 / 디저트
# 29406     스시이젠  4.2   서울특별시 용산구 한강대로 95 래미안용산 더 센트럴 B2 247호           회 / 스시
# 29422  오근내2닭구이  4.2               서울특별시 용산구 한강대로11길 13 용일빌딩        닭 / 오리 요리
# 29437    3F 로비  4.1                 서울특별시 용산구 한강대로15길 19-19         카페 / 디저트
# 29447      루블랑  4.1                    서울특별시 용산구 한강대로15길 23           프랑스 음식
# 29457    FOURB  4.4           서울특별시 용산구 한강대로21나길 17 리빙파크 4F         카페 / 디저트
# ...

# %%
store_name_5 = store_name.sort_values(by='평점',ascending=False)[:5]

# %%
loc_store = []

for i in store_name_5.index:
    geocode_result = gmaps.geocode(store_name_5['주소'][i])
    geometry=geocode_result[0].get("geometry")
    location=geometry.get("location")
    lng=location.get("lng")
    lat=location.get("lat")
    loc = lat,lng
    loc_store.append(loc)
loc_store
# Out:
# [(37.529614, 126.9700702),
#  (37.5242567, 126.970731),
#  (37.5288539, 126.9640447),
#  (37.5301149, 126.9699637),
#  (37.5301149, 126.9699637)]

# %% [markdown]
# ## 함수로 전체 합치기

# %%
def center_pointer(num_points):
    latitude=[]
    longitude=[]
    coordinate=[]
    
    for i in range(num_points):
        address = input("도로명주소를 입력하세요: ")
        geocode_result = gmaps.geocode(address)
        geometry=geocode_result[0].get("geometry")
        location=geometry.get("location")
        lng=location.get("lng")
        lat=location.get("lat")
        latitude.append(lat)
        longitude.append(lng)
        coordinate.append((lat, lng))

    center_point=(sum(latitude)/len(latitude), sum(longitude)/len(longitude))
    map=folium.Map(location=[center_point[0], center_point[1]], zoom_start=12)
    folium.Marker([center_point[0], center_point[1]], popup="center", icon=folium.Icon(color="red")).add_to(map)
    folium.CircleMarker([center_point[0], center_point[1]], radius=50, color="skyblue", fill_color="skyblue").add_to(map)
    for i in range(len(coordinate)):
        folium.Marker([latitude[i], longitude[i]], popup="출발지점 {}, {}km 거리입니다.".format(i, round(haversine(coordinate[i], center_point), 2))).add_to(map)
        folium.PolyLine(locations=[coordinate[i], center_point],weight=2, color = 'blue').add_to(map)
    
    # center_point의 주소 
    center_addr = gmaps.reverse_geocode((center_point), language='ko')[0]['formatted_address']
    
    # 먼저 center_point와 같은 구인 가게 추출 (시간을 줄이기 위해서)
    store_list = []
    for i in df_store.index:
        if (center_addr[11:13] in df_store['주소'][i]):
            store_list.append(df_store.loc[i])
    store_list = pd.DataFrame(store_list)
    
    # 그 중 center_point로부터 1km 이내의 가게들만 추출
    store = []
    for i in tqdm(store_list.index):
        result = gmaps.geocode(store_list['주소'][i])
        geometry = result[0].get("geometry")
        lat = geometry['location']['lat'] # 가게 위도
        lng = geometry['location']['lng'] # 가게 경도
        point = lat,lng

        if (haversine(point, center_point)) <= 1:
            store.append(df_store.loc[i])
    
    store = pd.DataFrame(store)
    store_name = store.drop_duplicates(['이름'])
    
    # 평점에 따른 상위 5개 가게
    store_name_5 = store_name.sort_values(by='평점',ascending=False)[:5]
    
    loc_store = []
    
    # 가게 위도 경도 추출
    for i in store_name_5.index:
        geocode_result = gmaps.geocode(store_name_5['주소'][i])
        geometry=geocode_result[0].get("geometry")
        location=geometry.get("location")
        lat=location.get("lat")
        lng=location.get("lng")
        loc = lat,lng
        loc_store.append(loc)
    
    for i in range(len(loc_store)):
        folium.Marker([loc_store[i][0], loc_store[i][1]], popup=store_name_5['이름'].values[i], icon=folium.Icon(color="green",icon="star")).add_to(map)
    return map

# %%
center_pointer(3)
# Out:
# 도로명주소를 입력하세요: 서울 종로구 율곡로 62
# 도로명주소를 입력하세요: 서울 종로구 대학로 120
# 도로명주소를 입력하세요: 서울 중구 퇴계로 126
# 100%|██████████████████████████████████████████████████████████████████████████████| 2211/2211 [04:27<00:00,  8.28it/s]
# ...
