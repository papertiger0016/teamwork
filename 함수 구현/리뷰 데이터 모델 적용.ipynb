# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import re

from tqdm import tqdm_notebook
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 경고표시 지우기
import warnings
warnings.filterwarnings(action="ignore")

# %%
filepath = "./data/model/model_lstm_220110.h5"

model = load_model(filepath, custom_objects=None, compile=True)

# %%
dir(model)
# Out:
# ['_TF_MODULE_IGNORED_PROPERTIES',
#  '__call__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_activity_regularizer',
#  '_add_trackable',
#  '_add_variable_with_custom_getter',
#  '_assert_compile_was_called',
#  '_assert_weights_created',
#  '_auto_track_sub_layers',
#  '_autocast',
#  '_autographed_call',
#  '_base_model_initialized',
#  '_build_graph_network_for_inferred_shape',
#  '_build_input_shape',
#  '_call_accepts_kwargs',
#  '_call_arg_was_passed',
#  '_call_fn_arg_defaults',
#  '_call_fn_arg_positions',
#  '_call_fn_args',
#  '_call_full_argspec',
#  '_callable_losses',
#  '_cast_single_input',
#  '_check_call_args',
#  '_checkpoint_dependencies',
#  '_clear_losses',
#  '_compile_was_called',
#  '_compiled_trainable_state',
#  '_compute_dtype',
#  '_compute_dtype_object',
#  '_compute_output_and_mask_jointly',
#  '_compute_tensor_usage_count',
#  '_configure_steps_per_execution',
#  '_conform_to_reference_input',
#  '_created_nodes',
#  '_dedup_weights',
#  '_default_training_arg',
#  '_deferred_dependencies',
#  '_distribution_strategy',
#  '_dtype',
#  '_dtype_defaulted_to_floatx',
#  '_dtype_policy',
#  '_dynamic',
#  '_eager_losses',
#  '_enable_dict_to_input_mapping',
#  '_expects_mask_arg',
#  '_expects_training_arg',
#  '_feed_input_names',
#  '_feed_input_shapes',
#  '_feed_inputs',
#  '_flatten',
#  '_flatten_layers',
#  '_flatten_to_reference_inputs',
#  '_functional_construction_call',
#  '_gather_children_attribute',
#  '_gather_saveables_for_checkpoint',
#  '_get_call_arg_value',
#  '_get_callback_model',
#  '_get_compile_args',
#  '_get_distribution_strategy',
#  '_get_existing_metric',
#  '_get_input_masks',
#  '_get_node_attribute_at_index',
#  '_get_optimizer',
#  '_get_save_spec',
#  '_get_trainable_state',
#  '_graph_initialized',
#  '_graph_network_add_loss',
#  '_graph_network_add_metric',
#  '_handle_activity_regularization',
#  '_handle_deferred_dependencies',
#  '_handle_deferred_layer_dependencies',
#  '_handle_weight_regularization',
#  '_has_explicit_input_shape',
#  '_in_multi_worker_mode',
#  '_inbound_nodes',
#  '_infer_output_signature',
#  '_inferred_input_shape',
#  '_init_batch_counters',
#  '_init_call_fn_args',
#  '_init_graph_network',
#  '_init_set_name',
#  '_initial_weights',
#  '_input_coordinates',
#  '_input_dtype',
#  '_input_layers',
#  '_input_spec',
#  '_insert_layers',
#  '_is_compiled',
#  '_is_graph_network',
#  '_is_layer',
#  '_is_layer_name_unique',
#  '_keras_api_names',
#  '_keras_api_names_v1',
#  '_keras_tensor_symbolic_call',
#  '_layer_call_argspecs',
#  '_layer_checkpoint_dependencies',
#  '_layers',
#  '_list_extra_dependencies_for_serialization',
#  '_list_functions_for_serialization',
#  '_lookup_dependency',
#  '_losses',
#  '_map_resources',
#  '_maybe_build',
#  '_maybe_cast_inputs',
#  '_maybe_create_attribute',
#  '_maybe_initialize_trackable',
#  '_maybe_load_initial_epoch_from_ckpt',
#  '_metrics',
#  '_metrics_lock',
#  '_must_restore_from_config',
#  '_name',
#  '_name_based_attribute_restore',
#  '_name_based_restores',
#  '_name_scope',
#  '_nested_inputs',
#  '_nested_outputs',
#  '_network_nodes',
#  '_no_dependency',
#  '_nodes_by_depth',
#  '_non_trainable_weights',
#  '_obj_reference_counts',
#  '_obj_reference_counts_dict',
#  '_object_identifier',
#  '_outbound_nodes',
#  '_output_coordinates',
#  '_output_layers',
#  '_output_mask_cache',
#  '_output_shape_cache',
#  '_output_tensor_cache',
#  '_predict_counter',
#  '_preload_simple_restoration',
#  '_reset_compile_cache',
#  '_restore_from_checkpoint_position',
#  '_run_eagerly',
#  '_run_internal_graph',
#  '_saved_model_inputs_spec',
#  '_self_name_based_restores',
#  '_self_saveable_object_factories',
#  '_self_setattr_tracking',
#  '_self_unconditional_checkpoint_dependencies',
#  '_self_unconditional_deferred_dependencies',
#  '_self_unconditional_dependency_names',
#  '_self_update_uid',
#  '_set_call_arg_value',
#  '_set_connectivity_metadata',
#  '_set_dtype_policy',
#  '_set_inputs',
#  '_set_mask_keras_history_checked',
#  '_set_mask_metadata',
#  '_set_output_names',
#  '_set_save_spec',
#  '_set_trainable_state',
#  '_set_training_mode',
#  '_setattr_tracking',
#  '_should_cast_single_input',
#  '_should_compute_mask',
#  '_should_eval',
#  '_single_restoration_from_checkpoint_position',
#  '_split_out_first_arg',
#  '_stateful',
#  '_steps_per_execution',
#  '_supports_masking',
#  '_symbolic_call',
#  '_tensor_usage_count',
#  '_test_counter',
#  '_tf_api_names',
#  '_tf_api_names_v1',
#  '_thread_local',
#  '_track_trackable',
#  '_trackable_saved_model_saver',
#  '_trackable_saver',
#  '_tracking_metadata',
#  '_train_counter',
#  '_trainable',
#  '_trainable_weights',
#  '_training_state',
#  '_unconditional_checkpoint_dependencies',
#  '_unconditional_dependency_names',
#  '_undeduplicated_weights',
#  '_update_uid',
#  '_updated_config',
#  '_updates',
#  '_use_legacy_deferred_behavior',
#  '_validate_compile',
#  '_validate_graph_inputs_and_outputs',
#  '_warn_about_input_casting',
#  'activity_regularizer',
#  'add',
#  'add_loss',
#  'add_metric',
#  'add_update',
#  'add_variable',
#  'add_weight',
#  'apply',
#  'build',
#  'built',
#  'call',
#  'compile',
#  'compiled_loss',
#  'compiled_metrics',
#  'compute_mask',
#  'compute_output_shape',
#  'compute_output_signature',
#  'count_params',
#  'distribute_strategy',
#  'dtype',
#  'dynamic',
#  'evaluate',
#  'evaluate_generator',
#  'fit',
#  'fit_generator',
#  'from_config',
#  'get_config',
#  'get_input_at',
#  'get_input_mask_at',
#  'get_input_shape_at',
#  'get_layer',
#  'get_losses_for',
#  'get_output_at',
#  'get_output_mask_at',
#  'get_output_shape_at',
#  'get_updates_for',
#  'get_weights',
#  'history',
#  'inbound_nodes',
#  'input',
#  'input_mask',
#  'input_names',
#  'input_shape',
#  'input_spec',
#  'inputs',
#  'layers',
#  'load_weights',
#  'loss',
#  'losses',
#  'make_predict_function',
#  'make_test_function',
#  'make_train_function',
#  'metrics',
#  'metrics_names',
#  'name',
#  'name_scope',
#  'non_trainable_variables',
#  'non_trainable_weights',
#  'optimizer',
#  'outbound_nodes',
#  'output',
#  'output_mask',
#  'output_names',
#  'output_shape',
#  'outputs',
#  'pop',
#  'predict',
#  'predict_classes',
#  'predict_function',
#  'predict_generator',
#  'predict_on_batch',
#  'predict_proba',
#  'predict_step',
#  'reset_metrics',
#  'reset_states',
#  'run_eagerly',
#  'save',
#  'save_weights',
#  'set_weights',
#  'state_updates',
#  'stateful',
#  'stop_training',
#  'submodules',
#  'summary',
#  'supports_masking',
#  'test_function',
#  'test_on_batch',
#  'test_step',
#  'to_json',
#  'to_yaml',
#  'train_function',
#  'train_on_batch',
#  'train_step',
#  'trainable',
#  'trainable_variables',
#  'trainable_weights',
#  'updates',
#  'variables',
#  'weights',
#  'with_name_scope']

# %%
def clean_str(string):    
    string = re.sub(r"[^가-힣A-Za-z0-9(),!?\'\`]", " ", string)
    string = re.sub(r"\'s", " \'s", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"n\'t", " n\'t", string)
    string = re.sub(r"\'re", " \'re", string)
    string = re.sub(r"\'d", " \'d", string)
    string = re.sub(r"\'ll", " \'ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)
    string = re.sub(r"\'{2,}", "\'", string)
    string = re.sub(r"\'", "", string)

    return string.lower()

df = pd.read_csv("./data/review_data/total_review.csv", encoding="utf-8-sig", index_col=0)
review_df = df.dropna(axis=0)

# 컬럼 재배치
# review_df = review_df[["review","score"]]

# clean_str 함수를 통해서 X데이터를 정제해주어야함.
# train_test_X = [clean_str(sentence) for sentence in review_df["review"]]
# # 문장을 띄어쓰기 단위로 단어 분리
# sentences = [sentence.split(' ') for sentence in train_test_X]
# for i in range(5):
#     print(sentences[i])

# # 문장의 길이를 그래프화
# sentence_len = [len(sentence) for sentence in sentences]
# sentence_len.sort()
# plt.plot(sentence_len)
# plt.show()

# # 총 3956974행의 데이터 중 30문장이내의 데이터는 3401248으로 85.9%에 육박.
# # 따라서, padding의 기준을 30로 잡겠음.
# print(sum([int(l<=30) for l in sentence_len]))
    
# sentence_new = []
# for sentence in sentences:
#     sentence_new.append([word[:5] for word in sentence][:30])

# sentences = sentence_new

# for i in range(5):
#     print(sentences[i])

# tokenizer = Tokenizer(num_words=3000)
# tokenizer.fit_on_texts(sentences)

# %%
mango = pd.read_excel("./data/망고플레이트 리뷰 종합.xlsx")

mango
# Out:
#        Unnamed: 0       이름       평점                       주소            주력 메뉴  \
# 0          3869.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# 1          3865.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# 2          3867.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# 3          3868.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# 4          3863.0     청우참치  \n4.5\n       서울특별시 강남구 강남대로 632       \n회 / 스시\n
# ...           ...      ...      ...                      ...              ...
# 36203         NaN  키미노돼지국밥        -  서울특별시 중랑구 중랑천로10길 92 1F  \n탕 / 찌개 / 전골\n
# 36204         NaN    조개나루터        -     서울특별시 중랑구 중랑천로12길 59       \n해산물 요리\n
# 36205         NaN    조개나루터        -     서울특별시 중랑구 중랑천로12길 59       \n해산물 요리\n
# 36206         NaN    제주돈선생        -     서울특별시 중랑구 중랑천로12길 61        \n고기 요리\n
# 36207         NaN    제주돈선생        -     서울특별시 중랑구 중랑천로12길 61        \n고기 요리\n
#
#           가격대                                          망고플레이트 주소  \
# 0      4만원 이상  https://www.mangoplate.com//restaurants/YyRGx0...
# 1      4만원 이상  https://www.mangoplate.com//restaurants/YyRGx0...
# 2      4만원 이상  https://www.mangoplate.com//restaurants/YyRGx0...
# 3      4만원 이상  https://www.mangoplate.com//restaurants/YyRGx0...
# 4      4만원 이상  https://www.mangoplate.com//restaurants/YyRGx0...
# ...       ...                                                ...
# 36203   만원 미만  https://www.mangoplate.com//restaurants/OGDe64...
# 36204     NaN  https://www.mangoplate.com//restaurants/MgyUt1...
# 36205     NaN  https://www.mangoplate.com//restaurants/MgyUt1...
# 36206  만원-2만원  https://www.mangoplate.com//restaurants/JtAAHT...
# 36207  만원-2만원  https://www.mangoplate.com//restaurants/JtAAHT...
#
#                                                     리뷰내용
# 0      \n          가로수길에 있는 오랜 참치맛집 e-청우참치위치를 옮기다!!원래...
# 1      \n          가성비 너무 좋고, 정말 양질의 참치를 양껏 즐길 수 있어서 ...
# 2      \n          가성비 좋은 한국식 참치횟집. 선도가 꽤 좋다. 카운터석도 있...
# 3        \n          그저 박수만. 참치땡길때 여기만한 곳이 없다.\n
# 4           \n          맛있다.. 느끼해서 많이 못먹는게 함정.\n
# ...                                                  ...
# 36203  \n          뜨끈한 돼지국밥 생각 날 때 자주 찾는 곳.멀리서도 먹으러 찾...
# 36204  \n          11월말에 처음 가보고나서 12~1월두달동안 벌써 8번이나 다...
# 36205  \n          가리비크기 미친거아닌가요.......내일 또갈래요..........
# 36206  \n          굳이 없는 식당까지 등록해가며 쓰지 않는데, 고기도 맛있고 사...
# 36207  \n          완전 맛있네오̊̈!̆̈  전 김치찌개 너무 맛있었어요 죽이 별...
#
# [36208 rows x 8 columns]

# %%
mango_sentence = []
for review in mango.iloc[:20,-1]:
    mango_sentence.append(review)
    
mango_sentence

mango_score = []
for score in mango.iloc[:20,2]:
    mango_score.append(score)
    
mango_score
# Out:
# ['\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.5\n',
#  '\n4.3\n',
#  '\n4.3\n',
#  '\n4.3\n',
#  '\n4.3\n',
#  '\n4.3\n']

# %%
cnt = 0

# 망고플레이트 리뷰 테스트
for review in mango_sentence:
    test_sentence = review
    test_sentence = test_sentence.split(' ')
    test_sentences = []
    now_sentence = []
    for word in test_sentence:
        now_sentence.append(word)
        test_sentences.append(now_sentence[:])
        
    tokenizer = Tokenizer(num_words=3000)
    tokenizer.fit_on_texts(test_sentences)
        
    test_X_1 = tokenizer.texts_to_sequences(test_sentences)
    test_X_1 = pad_sequences(test_X_1, padding='post', maxlen=30)
    prediction = model.predict(test_X_1)
    for idx, sentence in enumerate(test_sentences):
#         print(sentence)
#         print((prediction[idx]).round(3))
        review_score = np.argmax((prediction[idx]).round(3))
    # print(review)
    print(review_score)
    print(mango_score[cnt])
    print("-"*70)
    cnt+=1

# tmp_score_list = []
# cnt = 1

# for data in review_score:
#     if not tmp_score_list:
#         tmp_score_list.append(data)
#     else:
#         tmp_score_list.append(data)
#         if tmp_score_list[0] > tmp_score_list[1]:
#             del tmp_score_list[1]
#         else:
#             del tmp_score_list[0]
    
# print(tmp_score_list)
    
# print(tmp_score_list)
# 띄어쓰기 기준으로 끊는 것이니
# Out:
# 3
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.5
#
# ----------------------------------------------------------------------
# 5
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.5
#
# ----------------------------------------------------------------------
# 5
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.5
#
# ----------------------------------------------------------------------
# 5
#
# 4.5
#
# ----------------------------------------------------------------------
# 5
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.5
#
# ----------------------------------------------------------------------
# 5
#
# 4.5
#
# ----------------------------------------------------------------------
# 5
#
# 4.5
#
# ----------------------------------------------------------------------
# 4
#
# 4.3
#
# ----------------------------------------------------------------------
# 4
#
# 4.3
#
# ----------------------------------------------------------------------
# 4
#
# 4.3
#
# ----------------------------------------------------------------------
# 5
#
# 4.3
#
# ----------------------------------------------------------------------
# 4
#
# 4.3
#
# ----------------------------------------------------------------------

# %%
# 망고 플레이트에서 가게 랜덤으로 뽑아서 점수 예측.

import random

cnt = 0

mango_store_list = []

for store in mango["이름"].unique():
    mango_store_list.append(store)

choiceList = random.choice(mango_store_list)

data = mango[mango["이름"]==choiceList]
print("뽑은 가게는 {}입니다.".format(str(data["이름"].unique())))

# 망고플레이트 리뷰 테스트
for review in data.iloc[:,-1]:
    test_sentence = review
    test_sentence = test_sentence.split(' ')
    test_sentences = []
    now_sentence = []
    for word in test_sentence:
        now_sentence.append(word)
        test_sentences.append(now_sentence[:])

    test_X_1 = tokenizer.texts_to_sequences(test_sentences)
    test_X_1 = pad_sequences(test_X_1, padding='post', maxlen=30)
    prediction = model.predict(test_X_1)
    for idx, sentence in enumerate(test_sentences):
#         print(sentence)
#         print((prediction[idx]).round(3))
        review_score = np.argmax((prediction[idx]).round(3))
    # print(review)
    print("리뷰\n", review)
    print("실제 점수 : ", data.iloc[cnt,2])
    print("예측한 점수 : ", review_score)
#     print(mango_score[cnt])
    print("-"*70)
    cnt+=1
# Out:
# 뽑은 가게는 ['뽀르누서울']입니다.
# 리뷰
#
#            서울의 놀리타?! 와 어쩜 이런 곳에!!! 이 동네를 살지 않고서야 이 곳의 존재를 알기도, 먹으러 가기도 쉽지 않아요. 하... 이렇게 한숨 나오는 이유는 찾기 애매하지만 맘에 들어서 또 와야하거든요. 진짜 작은 곳인데도 사람들이 잘 찾아오네요, 안에 테이블이 한 세개 있나..? 샌드위치나 수프등 음식이 빨리 솔드아웃됩니다.  “까놀리”☆ - 인생 첫 까놀리였는데, 바로 맛있음을 느꼈어요. 페이스트리껍질은 가볍고 매우 바삭!해요. 크림은 피스타치오맛인데 매우 맛있네요, 고소하고 달콤하고 라이트해요. 생각보다 커서 좋았는데 그래도 하나로는 부족!! “포카치아 샐러드 보울” - 먹기 전엔 약간 가격이 비싼듯했지만 포카치아 맛있으니 가격 생각은 바로 사라졌어요. 진짜 이탈리아는 디저트까지 맛없는 게 없네!!다음에 또 와서 까놀리도 여러개 사고 샌디치도 티라미스도 바치디다마도 먹을 거에요. 다시 영업을 시작하실 날짜를 기다리며...
#
# 실제 점수 :
# 4.4
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           "한남동에서 느끼는 이탈리아의 맛."이탈리안 브런치 맛집 "뽀르누서울"에 가보았어요.미케타 샌드위치(+ 프로슈토 선택), 버섯 수프, 카놀리. 세 가지 주문해 먹어보았습니다.미케타 샌드위치는 바작한 빵 안에 두 가지 치즈, 바질 페스토, 루꼴라, 썬드라이 토마토가 들어가는 샌드위치예요.프로슈토, 치즈의 짭짤 꼬릿함과 썬드라이 토마토의 쫄깃함이 인상적이었어요. 진한 버섯 수프에는 크루통이 진짜 듬뿍 들어가 있었어요.오래 끓인 들깨국 느낌도 좀 나는 게 완전 제 스타일이었습니다. 다음에 가도 또 주문해 먹을 것 같아요.이탈리아 수제 디저트라는 카놀리는 바삭한 쉘 안에 부드럽고 은은한 피스타치오 리코타 크림이 든 디저트였어요.쉘에서 생과자 중에 "매작과" 느낌이 나서 넘 신기했어요.더해주신 오렌지로 더 맛있게 먹을 수 있었습니다.맛있는 음식과 좋은 공간, 세상 유쾌, 친절하셨던 사장님.또 가지 않을 이유가 없을 무인 곳이었습니다...! ㅎㅎ
#
# 실제 점수 :
# 4.4
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           <밀린 간식 리뷰 털이 3편><서빙고의 빛>말 그대로 서빙고의 빛. 작지만 강한 이탈리안 브런치 카페다. 친절함이 각별하시구 요리 실력도 탁월하신 사장님이 계시기에 앞으로 최소 10번은 더 가야 할 듯 하다.----------------------------------------------------------------------------------와인바 일로프 팝업에서 맛본 스튜와 아란치니도 맛있었지만 잠시 부활한 뽀르누를 만나고자 오신 분들이 워낙 많았던 터라 접객도 음식들의 온도감도 살짝 아쉬운 감이 없지 않았는데.. 올해 방문에서 확인했다. 여긴 진짜다.혼자 습격해 맛본 메뉴는 올리브 치킨 샌드위치, 양송이 수프, 수쁠리. 닭 안심과 올리브, 치즈, 파프리카 절임, 루꼴라가 푸짐하게 들어간 치킨 올리브 샌드위치는 양도, 맛도 최고였고 닭 날개 육수에 양송이 터프하게 때려 넣어 푹푹 끓여 주신 양송이 수프도 좋았다. 이촌에서 걸어 오느라 차게 식은 미련한 몸뚱아리, 단숨에 녹여 주었달까.수쁠리는 또 얼마나 맛있게요. 아란치니랑은 외양만 닮았을 뿐, 다르다. 그리고 더 맛있다!접객이야 여기 사장님 친절퀸이자 미소퀸으로 원체 유명하시니 굳이 설명 안 해도 될 것 같고..유일한 단점은 차 가져 가기도, 대중 교통으로 가기도 애매한 위치인데.. 개인적으로는 이촌이나 서빙고에서 걸어가는 걸 추천한다. 용산 공원이 생긴 지금은, 걸어가다 힘들면 용산 공원에서 좀 쉬다 가도 되기도 하고, 길 자체가 삼각지 길이나 한남동 길과 달리 아직 힙쟁이들에 짓밟히지 않은 길이라 용산 고유의 황량하면서도 운치 있는 매력이 잘 살아 있다.또 뭐든, 좀 걷고 먹어야 맛있기도 하지 않나. 먹은 뒤에도 좀 걸어야 소화 잘 되는 거구.아, 단점이 하나 더 있긴 하네. 생각보다 여기의 진가를 아는 이들이 꽤 먆다. 주말은 말할 것두 없고, 평일에도 보통 두 시 전에 식사 메뉴는 전부 품절된다.그래도 일찍 일어나 운동화 신고, 걷기 운동 제법 해서 찾을 가치가 충분한 업장이니 아직이신 분들, 다들 꼭 가 보시길 바랍니다. 한 번 가 보란 소리는 안 할게요. 한 번으로 끝낼 수 없을 테니까!*일단 여기까지. 곧 완성할게요~
#
# 실제 점수 :
# 4.4
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           샌드위치(6,0) 과일주스(5,0) 아메리카노(4,0) 스콘(4,0)-샌드위치가격에 비해 양이 적지않나 싶지만, 들어가는 재료들을 생각하면 괜찮은 가격인거 같아요. 마트산 치즈가 아니라 숙성치즈가 들어가고 파프리카 절임도 들어가는데 오 이것은 저세상 파프리카인가!! 말안해주셨으면 몰랐을것을! 파프리카가 쫀득하고 달달하구 샌드위치의 맛을 훅 올려주는 재료였어요. .스콘스콘치고 좀 비싼감이 있지만, 정말 초코칩 때려박은 완전리엉 스콘이라 만족했습니닼ㅎㅎ 느끼하지않고 담백한데  버터풍미가 느껴졌어요. 초코칩이 얼마나 꾸덕하고 맛있는지!!.아메리카노일단 컵부터 너무 힙한.. 독특한 컵이 진짜 넘 맘에들었어요. 바디감 묵직하고 고소한맛이었어요. 산미 없구요..인스타에 당일 라인업이 올라오니 확인하고 가세요! ㅎㅎ
#
# 실제 점수 :
# 4.4
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           여전히 맛있고 분위기도 너무 좋아요. 사장님이 참 유쾌하시네요. ㅎㅎ 인테리어가 바뀌었는데 바뀐것도 예뻐요. 아란치니 에피타이저로 먹었는데 정말 맛있었어요. 안에 라구소스에 치즈, 밥이 들어있어서 에피타이저 치곤 좀 무겁긴 합니다. 1pc에 4,5에요.샌드위치도 2가지 종류였는데 하나는(사진속 3등분 해서 나온것)발사믹과 바질페스토 맛이 강했어요. 다른 하나는 좀더 가벼운 느낌의 샌드위치였습니다. 야채 좋아하는 사람들에게 추천한다 하셨어요~
#
# 실제 점수 :
# 4.4
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           오랜만에 숨겨놓고 나만 알고 싶은 곳, 서울 속에 작은 이태리가 바로 여기에 있다 찾아가는 일조차가 고역이다 접근성도 불편하고 주택가라고 말하기조차 어려운 인적이 드문 곳에 위치한 것마저 모자라 주인 언니가 곧 출산 예정이라 언제 또 문을 닫을지도 모르겠다도착을 했다고 다가 아니다 좌석이 몇 개 없고, 그마저도 오픈전부터 웨이팅이 있어 언제 식사를 할 수 있을지도 모를, 더 절망적인 건(?) 만드는 양이 많지 않아 품절이 빨리 되버린다 그럼에도 불구하고 날이 풀리면 꼭 또 가고 싶은 그런 곳!인스타그램을 통해 전날 메뉴를 업데이트해서 메뉴가 종종 바뀌지만 그래도 런치 한끼 식사로 괜찮을 샌드위치나 리조또, 그리고 훌륭한 디저트까지 선보인다 토마토 스튜 - 올리브 포카치아와 같이 낸 소시지가 왕창 들어간 스튜는 식사를 시작하기에 적절했다 운좋게 날 좋은 날 야외 좌석에 앉아 먹는 스튜라니 이보다 더 행복한 한끼가 있을까샌드위치 - 스튜는 그래, 맛있지만 내가 스튜 먹으러 이 고생을 하며 다시는 안오겠다는 내 마음을 샌드위치가 완전히 바꿔놓았다 이 정도 퀄리티의 샌드위치라면 매달은 아니어도 적어도 분기당 이 고생을 하며 다시 와야겠다 흠 잡을 데 없는 이탈리안 샌드위치로 밸런스는 말해뭐해 빵이 다 했다바치디디마 - 서울 한복판에서 직접 만든 바치디디마를 먹을 수 있다니 가게의 시그니쳐 중 하나로 헤이즐넛을 직접 갈아 정성으로 만들어 풍미가 좋다까놀리 - 직접 만든 게 바치디디마 뿐만이 아니다 직접 만든 까놀리 역시 맛볼 수 있다 이쯤되면 여기가 이탈리아인지 어딘지 모르겠다 포장해 간 스콘 역시 맛있었다 그러나 역시 최고는 샌드위치와 디저트류!
#
# 실제 점수 :
# 4.4
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           피스타치오 카놀리 (6.0), 포르마지오 스콘, 바치디다마, 티라미수 등보광동 사랑방 느낌, 이탈리아 디저트 및 샌드위치 등을 맛볼수 있다. 라인업은 맨날 바뀌니 방문전 인스타그램 확인하는 것을 추천쉘에 리코타치즈와 피스타치오로 만든 필링을 가득 채워주는 피스타치오 카놀리, 헤이즐넛으로 만든 샌드쿠키인 바치디다마 등 흔치 않은 디저트를 접할 수 있다사진은 카놀리밖에 없다,,
#
# 실제 점수 :
# 4.4
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------

# %%
# 망고플레이트 리뷰 테스트
store = input("가게 이름을 입력하시오 : ")

data = mango[mango["이름"]==store]
if data.empty is True:
    print("데이터가 없습니다.")

else:
    score_sum = 0
    cnt=0

    for review in data.iloc[:,-1]:
        test_sentence = review
        test_sentence = test_sentence.split(' ')
        test_sentences = []
        now_sentence = []
        for word in test_sentence:
            now_sentence.append(word)
            test_sentences.append(now_sentence[:])

        test_X_1 = tokenizer.texts_to_sequences(test_sentences)
        test_X_1 = pad_sequences(test_X_1, padding='post', maxlen=30)
        prediction = model.predict(test_X_1)
        for idx, sentence in enumerate(test_sentences):
            review_score = np.argmax((prediction[idx]).round(3))
        print("리뷰\n", review)
        print("실제 점수 : ", data.iloc[cnt,2])
        print("예측한 점수 : ", review_score)
        print("-"*70)
        score_sum += review_score
        cnt+=1
    print("예측한 평균 평점 : {}".format((score_sum/cnt+1).round(2)))
# Out:
# 가게 이름을 입력하시오 : 청우참치
# 리뷰
#
#           가로수길에 있는 오랜 참치맛집 e-청우참치위치를 옮기다!!원래 있던 자리의 건물이 매각되어 바로 인근으로 옮기고 살짝 리모델링(?)까지는 아니지만 옮기고 아주 살짝 넒어진 느낌이지만 그래도 바테이블에 앉으면 엄청 다닥다닥 붙어 앉아야 하지만 정감가는 매력이 있는곳.이곳에서는 참치는 부위별로 다양한 맛을 즐길 수 있는데~ 원래 빨간부위를 좋아했는데 청우참치에서 다른 부위의 맛도 즐기게 됨 마블링있는 부위는 마치 소고기를 먹는것처럼 살짝 기름지면서 고소하고 부드러움 ㅠㅠ 더 많이 먹었어야 했는데 내 위가 왜 허락칠 않는거니ㅠㅠ 쓸데없이 감자랑 콘버터까지 맛있음... 예약을 잘 받지않아 대기해야하고 주말에도 예전에는 영업 안했는데 가시려면 확인하고 가야해요~^^
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  5
# ----------------------------------------------------------------------
# 리뷰
#
#           가성비 너무 좋고, 정말 양질의 참치를 양껏 즐길 수 있어서 더 좋다. 참치하면 청우참치 말고 다른 곳은 생각이 안난다...
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           가성비 좋은 한국식 참치횟집. 선도가 꽤 좋다. 카운터석도 있고 바닥에 양반다리 하고 앉아먹기도 하는 아저씨스타일집. 단촛물밥 달라고 해서 초밥으로 싸먹으면 맛있다. 분위기나 멋 포기하고 오로지 참치만 생각한다면 추천
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           그저 박수만. 참치땡길때 여기만한 곳이 없다.
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  3
# ----------------------------------------------------------------------
# 리뷰
#
#           맛있다.. 느끼해서 많이 못먹는게 함정.
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  2
# ----------------------------------------------------------------------
# 리뷰
#
#           신사동에 위치한 "e-청우참치". 평이 항상 좋아서 꼭 가보고 싶었던 참치 집!! 사장님 혼자서 참치를 썰어주는데, 태평양에서 참치를 어획하던 경험으로 참치를 엄선 하신다니 더 맛있게 느껴진다!! 추천!! : )'참치회'. 테이블에 앉으면 참치 한 판을 먼저 주시고 더 주시는 것 같던데, 우리는 테이블 자리에 앉아서 바로바로 참치를 놓아주셨어요. 사장님 혼자 하시는데도 참치 비는 타임 없이 잘 챙겨주심!! 역시 제일 맛있는 건 참치 뱃살!! 진짜 수박을 보는 것 같은 비쥬얼ㅋㅋ 와사비 듬뿍 해서 먹으니 입에서 녹는다 녹아ㅠㅠ 거기에 가져온 사케 (콜키지 만원) 한잔 캬~ 하니 일주일 간의 피로도 함께 녹아내리는 느낌!!분위기는 복작복작 술 먹는 분위기!! 사람이 정말 많더라구요. 한 일주일 전에 예약하고 갔는데, 불금엔 예약 필수인듯. 한시간 반정도 먹으니 엄청 배불리 먹고 나왔어요ㅋㅋ 참치집을 많이 가본 건 아니지만 여기 만한 집도 없을 것 같은 느낌!!
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  3
# ----------------------------------------------------------------------
# 리뷰
#
#           어제 저녁 두번째 방문..! 요근래 양도 줄고 술도 조금 줄어서 완전 박살나게 못먹은게 아쉽네요ㅎ  참치회는 왜 먹어도 먹어도 질리지가 않는걸까요...?  이 아름다운 마블링 하루만에 또 생각나네요
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  2
# ----------------------------------------------------------------------
# 리뷰
#
#           언제가 가봐야겠다하고명절 전날 일찍 끝나 가게된 청우참치메뉴는 단품 하나 55000원처음부터 끝까지 좋은 부위를 계속 주시는데 살살 녹음왜 3대 참치집중에 하나인줄 알겠음스끼는 간단히 나오지만참치에 충실하여 너무 좋다테이블보다는 닷지에 앉아서먹는 재미가 좋은듯한국에서 먹은 참치중 제일 맛있었다
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           오래전 저장만 해두고 언제쯤 갈수있을까 하다 드디어 갔는데어우 진짜...입에서 그냥 녹아요기름좔좔 해동도 너무 잘돼있고..맛있는 부위 다 골고루 내어주시고 퀄에비해 싼듯한 느낌마저...!바에 앉은 덕분에 끊이지않게 내어주심 사장님도 친절하시고, 인기가 많아서 가게는 좀 복잡하지만 기다려서 먹을 가치가 있었습니다 왕추천
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  3
# ----------------------------------------------------------------------
# 리뷰
#
#           완벽한 해동균일한 혼마구로 처음가도 단골과 차이없이 나오는 참치무한리필 참치 중에서는 단연 일등
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  2
# ----------------------------------------------------------------------
# 리뷰
#
#           정말 너무 맛있게 먹었던 참치집. 혈육이 참치사달라고 딱 이 가게를 골라왔길래 데리고 갔는데 맨처음엔 그냥 코스집인줄 알고 먹으면서 "가격에 비해 양이 많네^^~" 했는데 분명 코스 끝난거같았는데 계속 나오길래 그때 비로소 의심하고 물어봄 "여기 혹시 무한리필이야?".. 그만큼 무한리필이라고 의심못할정도로 퀄리티가 너무 괜찮아서 놀람ㅋㅋㅋ 콜키지도 싼것같던데 재방문한다면 그때는 꼭 사케 한병 들고가야지..!
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  2
# ----------------------------------------------------------------------
# 리뷰
#
#           참치만 드신다면 이 이상의 해동+퀄리티를 본적이 없습니다 최상위혼마구로를 원하는 부위로만 계속 내주십니다 값도 5만원 엄청 저렴한 편입니다 정말 대단한건 그비싼 신사동 땅값에 점심도 운영 안하시고 평일 주5일영업 공휴일 전부 휴무입니다이렇게 영업하는 식당은 흔하지 않을겁니다  ㅎ 베스트 참치집!
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           참치의 최상급부위를 계속 먹을수있다!!
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  5
# ----------------------------------------------------------------------
# 리뷰
#
#           최고입니다
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  4
# ----------------------------------------------------------------------
# 리뷰
#
#           퀄리티 좋은 참치회를 무한으로 즐겨요10월 1일이 니혼슈의 날인 것 다들 아시나요..?! 니혼슈의 날 기념 사케를 입수해서 니혼슈의 날(근처에)에 콜키지해서 마시려고 찾다 친구추천으로 방문한 곳입니다.6만원에 참치 무한리필(?)이구요. 죽을 포함한 반찬 몇가지 다음으로 참치 모듬 판이 뙇 나옵니다. 기름지고 해동 잘된 참치를 부위별로 맛볼 수 있었는데요. 참치가 전체적으로 기름져서 그런지 사케가 쭉쭉 들어가더라구요. 참치 퀄리티는 근막이 씹히는 곳이 복불복으로 있긴 했는데 비린내도 없고 전체적으로 맛있었습니다.가성비좋게 사케 마시러 가기 딱이예요. 재방문의사O
#
# 실제 점수 :
# 4.5
#
# 예측한 점수 :  3
# ----------------------------------------------------------------------
# 예측한 평균 평점 : 4.33

# %%
##### 정리


##### import Library #####
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
import re
import random

from tqdm import tqdm_notebook
from sklearn.model_selection import train_test_split
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# 경고표시 지우기
import warnings
warnings.filterwarnings(action="ignore")
##### import Library #####

##### function #####
def clean_str(string):    
    string = re.sub(r"[^가-힣A-Za-z0-9(),!?\'\`]", " ", string)
    string = re.sub(r"\'s", " \'s", string)
    string = re.sub(r"\'ve", " \'ve", string)
    string = re.sub(r"n\'t", " n\'t", string)
    string = re.sub(r"\'re", " \'re", string)
    string = re.sub(r"\'d", " \'d", string)
    string = re.sub(r"\'ll", " \'ll", string)
    string = re.sub(r",", " , ", string)
    string = re.sub(r"!", " ! ", string)
    string = re.sub(r"\(", " \( ", string)
    string = re.sub(r"\)", " \) ", string)
    string = re.sub(r"\?", " \? ", string)
    string = re.sub(r"\s{2,}", " ", string)
    string = re.sub(r"\'{2,}", "\'", string)
    string = re.sub(r"\'", "", string)

    return string.lower()

def model_load(file_path):
    print("모델 불러오는 중...")
    # model load
    filepath = file_path
    model = load_model(filepath, custom_objects=None, compile=True)
    
    return model

def data_load(dataframe):
    print("데이터 불러오는 중...")
    df = pd.read_csv(dataframe, encoding="utf-8-sig", index_col=0)
    review_df = df.dropna(axis=0)
    
    return review_df

def model_random_test(mango):
    print("모델 테스트 중...")
    # 망고 플레이트에서 가게 랜덤으로 뽑아서 점수 예측.
    cnt = 0
    score_sum = 0
    mango_store_list = []
    try:
        for store in mango["이름"].unique():
            mango_store_list.append(store)

        choiceList = random.choice(mango_store_list)

        data = mango[mango["이름"]==choiceList]
        print("뽑은 가게는 {}입니다.".format(str(data["이름"].unique())))

        score = 0
    except:
        print("망고플레이트 Database안에 없는 가게입니다.")

    # 망고플레이트 리뷰 테스트
    for review in data.iloc[:,-1]:
        test_sentence = review
        test_sentence = test_sentence.split(' ')
        test_sentences = []
        now_sentence = []
        for word in test_sentence:
            now_sentence.append(word)
            test_sentences.append(now_sentence[:])
            
        tokenizer = Tokenizer(num_words=3000)

        test_X_1 = tokenizer.texts_to_sequences(test_sentences)
        test_X_1 = pad_sequences(test_X_1, padding='post', maxlen=30)
        prediction = model.predict(test_X_1)
        for idx, sentence in enumerate(test_sentences):
            review_score = np.argmax((prediction[idx]).round(3))
            
        print("리뷰\n", review)
        print("실제 점수 : ", data.iloc[cnt,2])
        print("예측한 점수 : ", review_score)
        print("-"*70)
        
        score_sum += review_score
        cnt+=1
    print("예측한 평균 평점 : {}".format(((score_sum/cnt).round(2))))

def model_test(mango):
    print("모델 테스트 중...")
    print("리뷰 모델 테스트.")
    store = input("가게 이름을 입력하시오 : ")

    data = mango[mango["이름"]==store]
    if data.empty is True:
        print("Database에 해당 가게가 없습니다.")

    else:    
        score_sum = 0
        cnt=0

        for review in data.iloc[:,-1]:
            test_sentence = review
            test_sentence = test_sentence.split(' ')
            test_sentences = []
            now_sentence = []
            for word in test_sentence:
                now_sentence.append(word)
                test_sentences.append(now_sentence[:])

            tokenizer = Tokenizer(num_words=3000)
            
            test_X_1 = tokenizer.texts_to_sequences(test_sentences)
            test_X_1 = pad_sequences(test_X_1, padding='post', maxlen=30)
            prediction = model.predict(test_X_1)
            for idx, sentence in enumerate(test_sentences):
                review_score = np.argmax((prediction[idx]).round(3))
            print("리뷰\n", review)
            print("실제 점수 : ", data.iloc[cnt,2])
            print("예측한 점수 : ", review_score)
            print("-"*70)
            score_sum = score_sum + review_score
            cnt+=1
        print("예측한 평균 평점 : {}".format((score_sum/cnt).round(2)))
        
##### function #####

##### Main #####
if __name__  == "__main__":
    
    path = "./data/model/model_lstm_220110.h5"
    model = model_load(file_path = path)
    
    data = "./data/review_data/total_review.csv"
    df = data_load(data)
    
    # 망고플레이트 리뷰 데이터
    mango = pd.read_excel("./data/망고플레이트 리뷰 종합.xlsx")
    
    opinion = input("어느 기능을 사용하시겠습니까(1:작동테스트 / 2:가게입력) : ")
    if opinion == "1":
        model_random_test(mango=mango)
    elif opinion == "2":
        model_test(mango=mango)
    else:
        print("번호를 잘못 입력하셨습니다. 1번과 2번중 골라주세요.")
# Out:
# 모델 불러오는 중...
# 데이터 불러오는 중...
# 어느 기능을 사용하시겠습니까(1:작동테스트 / 2:가게입력) : 1
# 모델 테스트 중...
# 뽑은 가게는 ['차고버거']입니다.
# 리뷰
#
#            차고버거 (화-토 11:30-21:30 일 11:30-21:00평일 브레이크타임 15:00-17:00) 서울 송파구 오금로11길 61-11 1층 101호✔️ 차고버거 클래식, 치즈프라이꽤나 찾기 어려운 자리에 있는 차고버거.이 자리에 아 가게가? 싶을 수도 있는 위치지만 그래도 건재하게 잘 있는 가게이다. 몇 년동안 먹고 있는데 늘 변함없는 맛을 선사해줘서 먹으면 실망이 없다.- 차고버거 클래식은 클래식인 이름에 맞게 고기 패티와 다른 야채들로 만들어졌다. 적양파가 생으로 나오기 때문에 양파 맛이 강하다. - 치즈프라이가 특이하게 나초와 같이 나온다. 프라이가 그냥 두툼한 맛이라면 나초가 바삭해서 둘을 같이 먹으면 맛있다. 치즈프라이 위에는 치즈소스를 올리는데 비주얼이 딱 군침 도는 맛.늘 만족하면서 먹는 가게다. 이 가게의 장점은 두툼한 고기패티와 프라이 소스! 애견 동반도 가능한 가게이기 때문에 견주분들도 마음껏 이용 가능한 곳!⏰ 주말 점심 방문 기준 대기 없음.
#
# 실제 점수 :
# 4.2
#
# 예측한 점수 :  5
# ----------------------------------------------------------------------
# 리뷰
#
#           먹다가 급히 올리는 바람에 사진이 개떡같이 나왔지만정말 맛있다 배 안에 여유가 될것 같다면 프라이도 꼭 먹어보길 바란다.이곳의 유일한 단점은 길건너의 모텔인듯 하다.
#
# 실제 점수 :
# 4.2
#
# 예측한 점수 :  5
# ----------------------------------------------------------------------
# 리뷰
#
#           무지막지한 감튀 사이즈. 진한 맛의 맛있는 수제버거. 집에 가려면 뒤뚱뒤뚱 배를 부여잡고 열심히 걸어야한다.
#
# 실제 점수 :
# 4.2
#
# 예측한 점수 :  5
# ----------------------------------------------------------------------
# 리뷰
#
#           자리에서 큐알코드로 주문하는게 신기했음 버거도 내용도 풍성하고감튀도 맛있고...모텔촌 사이에 있어서 길치는 살짝 찾기 힘들었음...추천~
#
# 실제 점수 :
# 4.2
#
# 예측한 점수 :  5
# ----------------------------------------------------------------------
# 리뷰
#
#           차고버거_수제버거부문 맛집(1)최초방문_'21년 8월1. 어릴적 사먹던 빵집 햄버거 부터, 패스트푸드, 수제버거, 심지어는 군대리아까지 곰곰이 생각해보면 버거는 국밥만큼이나 누구나 쉽게 접할수 있는 음식이다. 이런 접하기 쉬운 음식들은 맛의 기준이 정말 다양하다. 가장 중요하게 여기는 요소가 패티의 진득한 육향일 수가 있고, 빵이 될 수도 있고, 함께들어간 야채 혹은 소스와의 밸런스가 될수도 있다.2. 내가 수제버거에서 가장 바라는 요소는 아마 패티가 아닐까 한다. 그런 의미에서는 조금 아쉬운 버거였다. 다만, 버거자체의 밸런스가 샌드위치에서나 바랄 만큼 좋았고, 새로운 맛을 느낄수 있어서 좋았다.(저는 패티에서 육즙이 줄줄흘러내리는 진한 고기맛을 가장 좋아합니다.)3. 메뉴는 "차고버거, 아시안버거, 치즈프라이, 아이스커피, 밀크쉐이크"를 주문했다.  1) 차고버거 : 신선한 토마토, 적양파와 아삭거리는 저 이름모를 초록채소와 소스, 베이컨, 두꺼운 패티, 체다치즈, 딥한 빵까지 밸런스가 너무 좋다. 샌드위치에서나 기대할수있는 신선한 느낌을 받을수 있어서 좋았다.   2) 아시안버거 : 소스와 볶은 미니새송이버섯, 양파에 토마토, 고수, 패티, 소스, 딥한 빵의 조합이다. 미니새송이 덕분에 막 흘러내려 마지막엔 손으로 줍줍 하느라 손이 소스 범벅이 되었지만, 원래 버거는 마지막에 손가락을 입으로 씻는거라 배웠기에 큰 불편은 아니었다. 무엇보다 고수가 들어가 예상치못한 맛인데 기분좋은 맛이라 더욱 좋다.  3) 치즈프라이 : 케챱말고 옆의 소스가 무슨소스인진 모르겠는데, 체다치즈소스와 같이 찍어먹으면 기분좋은 맛이다 ㅋㅋㅋ 큰 임펙트는 없었지만 일반적인 감튀보단 좋았다 ㅋㅋ  4) 밀크쉐이크 : 후... 난 사실 밀크쉐이크에 감튀를 찍어먹는걸 별로 안좋아한다. 나도 왜그런진 모르겠는데, 단짠에 큰 매력을 못느낀다. 덕분에 버거집에서 밀크쉐이크를 잘 안시켜먹는데 이날은 이상하게 밀크쉐이크 자체가 당겨 시켰는데 ㅋㅋㅋㅋ 정말 맛있다.. 뭐.. 원래 밀크쉐이크가 이렇게 맛있나?? ㅋㅋㅋ 자주 안먹어서 몰랐는데 참 맛있닼ㅋㅋ4. 밸런스가 정말 좋았다. 아마, 샌드위치의 신선함이 그리울때 오히려 이곳에서 차고버거를 시켜먹을것 같다 ㅋㅋㅋㅋ 내가 가장 중요하게 생각하는 패티가 아쉬운것 빼고 사실 다 갖춘 느낌이다 ㅋㅋ ※ 결론다시 먹게된다면 다른메뉴보다 "차고버거"를 ㅋㅋ
#
# 실제 점수 :
# 4.2
#
# 예측한 점수 :  5
# ----------------------------------------------------------------------
# 예측한 평균 평점 : 5.0
# 25
# 5
